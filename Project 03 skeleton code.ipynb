# %% [markdown]
# ## part 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Function to plot PDFs and histograms
def plot_pdf(mu, sigma, label, alpha=0.5, linestyle='k--', density=True, color='green'):
    """
    Plot 1-D data and its corresponding PDF curve.
    
    Parameters:
    -----------
    mu : float
        Mean of the distribution.
    sigma : float
        Variance of the distribution.
    label : str
        Label for the plot (for legend).
    alpha : float, optional
        Transparency level for the histogram (default is 0.5).
    linestyle : str, optional
        Line style for the PDF curve (default is 'k--').
    density : bool, optional
        If True, normalize the histogram (default is True).
    color : str, optional
        Color of the plot (default is 'green').

    Returns:
    --------
    None
    """
   pass

# Plot intermediate steps
def plot_intermediate_steps(means, variances, pi, step):
    """
    Plot the intermediate steps of the GMM fitting process.
    
    Parameters:
    -----------
    means : array-like, shape (n_components,)
        Means of the Gaussian components.
    variances : array-like, shape (n_components,)
        Variances of the Gaussian components.
    pi : array-like, shape (n_components,)
        Mixture weights (probabilities) of each component.
    step : int
        Current step number for the iteration (used for labeling the plot).

    Returns:
    --------
    None
    """
    # Original distribution
    plot_pdf(mu1, sigma1, alpha=0.0, linestyle='r--', label='Original Distributions')
    plot_pdf(mu2, sigma2, alpha=0.0, linestyle='r--', label='Original Distributions')
    plot_pdf(mu3, sigma3, alpha=0.0, linestyle='r--', label='Original Distributions')
    
    color_gen = (x for x in ['green', 'blue', 'orange'])
    
    # Plot current state of means and variances
    for mu, sigma, pi in zip(means, variances, pi):
        plot_pdf(mu, sigma, alpha=0.5, label=f"Step {step} (pi={pi:.2f})", color=next(color_gen))
    
    plt.title(f"Step {step}: Intermediate Plot")
    plt.legend()
    plt.show()

# Function to initialize GMM parameters randomly
def random_init(n_components, X):
    """
    Initialize GMM parameters (means, variances, and mixture weights) randomly.
    
    Parameters:
    -----------
    n_components : int
        Number of Gaussian components in the mixture model.
    X : array-like, shape (n_samples,)
        Data points to initialize the means.

    Returns:
    --------
    means : array-like, shape (n_components,)
        Randomly initialized means for each component.
    variances : array-like, shape (n_components,)
        Randomly initialized variances for each component.
    pi : array-like, shape (n_components,)
        Initial mixture weights (set to uniform distribution).
    """
    pass

# E-step of EM algorithm
def step_expectation(X, n_components, means, variances, pi):
    """
    E Step: Calculate the responsibility matrix (weights).
    
    Parameters:
    -----------
    X : array-like, shape (n_samples,)
        The observed data points.
    n_components : int
        Number of Gaussian components in the mixture model.
    means : array-like, shape (n_components,)
        Current estimates of the means for each component.
    variances : array-like, shape (n_components,)
        Current estimates of the variances for each component.
    pi : array-like, shape (n_components,)
        Current estimates of the mixture weights for each component.

    Returns:
    --------
    weights : array-like, shape (n_components, n_samples)
        The responsibility matrix, where each element represents the
        probability of a data point belonging to a component.
    """
    pass

# M-step of EM algorithm
def step_maximization(X, weights):
    """
    M Step: Update the GMM parameters based on the current responsibilities.
    
    Parameters:
    -----------
    X : array-like, shape (n_samples,)
        The observed data points.
    weights : array-like, shape (n_components, n_samples)
        Responsibility matrix from the E-step.

    Returns:
    --------
    new_means : array-like, shape (n_components,)
        Updated means for each Gaussian component.
    new_variances : array-like, shape (n_components,)
        Updated variances for each Gaussian component.
    new_pi : array-like, shape (n_components,)
        Updated mixture weights (pi) for each component.
    """
    pzss

# Train the GMM model using EM
def train_gmm(data, n_components=3, n_steps=50):
    """
    Train the GMM model using the EM algorithm.
    
    Parameters:
    -----------
    data : array-like, shape (n_samples,)
        The observed data points to fit the GMM to.
    n_components : int, optional
        Number of Gaussian components in the mixture model (default is 3).
    n_steps : int, optional
        Number of iterations for the EM algorithm (default is 50).

    Returns:
    --------
    None
    """
    pass

# Generating synthetic data
n_samples = 100
mu1, sigma1 = -5, 1.2 
mu2, sigma2 = 5, 1.8 
mu3, sigma3 = 0, 1.6 

x1 = np.random.normal(loc=mu1, scale=np.sqrt(sigma1), size=n_samples)
x2 = np.random.normal(loc=mu2, scale=np.sqrt(sigma2), size=n_samples)
x3 = np.random.normal(loc=mu3, scale=np.sqrt(sigma3), size=n_samples)

#X = 

# Run GMM training
train_gmm(X, n_components=3, n_steps=30)

# %% [markdown]
# ## Part 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to generate synthetic 2D data
def generate_kmeans_data(n_samples=100):
    np.random.seed(42)
    x1 = np.random.randn(n_samples, 2) + np.array([4, 4])
    x2 = np.random.randn(n_samples, 2) + np.array([-4, -4])
    x3 = np.random.randn(n_samples, 2) + np.array([0, 0])
    return np.vstack((x1, x2, x3))

# Plot function for 2D data and centroids
def plot_kmeans_data(X, centroids=None, step=None):
    plt.scatter(X[:, 0], X[:, 1], c='gray', alpha=0.6, label="Data Points")
    if centroids is not None:
        plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='x', label="Centroids")
    if step is not None:
        plt.title(f"K-Means Step {step}")
    plt.legend()
    plt.show()

# Random initialization for K-means
def random_init_kmeans(X, k=3):
    pass
# Expectation step (Assignment)
def step_expectation_kmeans(X, centroids):
    pass

# Maximization step (Update centroids)
def step_maximization_kmeans(X, labels, k):
    pass

# K-means Training using EM approach
def train_kmeans_em(X, k=3, n_steps=10, plot_intermediate=True):
    pass

# Generate data and run K-Means
X = generate_kmeans_data()
train_kmeans_em(X, k=3, n_steps=10)

# %% [markdown]
# ### Q2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to load and preprocess image using plt.imread
def load_image(image_path):
    """ Load and preprocess the image as a 2D array of pixels in RGB space. """
    image = plt.imread(image_path)
    image = image / 255.0  # Normalize pixel values between 0 and 1
    pixels = image.reshape(-1, 3)  # Reshape into (num_pixels, 3) for RGB
    return pixels, image.shape

# Plot function to display original and clustered images
def plot_image(image_data, image_shape, title):
    """ Plot the original or clustered image. """
    image = image_data.reshape(image_shape)
    plt.imshow(image)
    plt.title(title)
    plt.axis('off')
    plt.show()

# Random initialization for K-means (EM-like approach)
def random_init_kmeans(pixels, k=3):
    """ Initialize centroids randomly from the image pixels. """
    pass

# Expectation step (Assignment of pixels to nearest centroids)
def step_expectation_kmeans(pixels, centroids):
    """ Assign each pixel to the nearest centroid using Euclidean distance. """
    pass

# Maximization step (Update centroids based on mean of assigned pixels)
def step_maximization_kmeans(pixels, labels, k):
    """ Update centroids based on the mean of the pixels assigned to each centroid. """
    centroids = np.array([pixels[labels == i].mean(axis=0) for i in range(k)])
    return centroids

# K-Means using EM-like approach for image segmentation
def train_kmeans_image(pixels, k=3, n_steps=10, image_shape=None):
    """ Train K-Means on image pixels using EM-like steps, and plot intermediate results. """
    pass

# Load image and run K-Means
image_path = 'china.jpg'  # Provide the path to your image
pixels, image_shape = load_image(image_path)
plot_image(pixels, image_shape, title="Original Image")  # Display original image

# Run K-Means segmentation with EM
k = 32  # Number of clusters/colors
centroids, labels = train_kmeans_image(pixels, k=k, n_steps=20, image_shape=image_shape)

# Final segmented image
segmented_image = centroids[labels]
plot_image(segmented_image, image_shape, title="Final Segmented Image")

# %% [markdown]
# ## Part 3

# %%
# Function to generate synthetic 3D data
def generate_ppca_data(n_samples=300):
    np.random.seed(42)
    X = np.random.multivariate_normal([5, 10, 15], np.diag([3, 2, 1]), n_samples)
    return X

# Plot function for original 3D data
def plot_3d_data(X):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(X[:, 0], X[:, 1], X[:, 2], c='blue', marker='o')
    plt.title("Original 3D Data")
    plt.show()

# Plot function for latent 2D data
def plot_2d_latent(Z, step=None):
    plt.scatter(Z[:, 0], Z[:, 1], c='red', marker='x')
    if step is not None:
        plt.title(f"PPCA Step {step}: Latent Space")
    plt.show()

# Random initialization for PPCA (initialize latent variables)
def random_init_ppca(X, latent_dim=2):
    pass

# Expectation step for PPCA (Estimate latent variables)
def step_expectation_ppca(X, W, sigma2):
    pass

# Maximization step for PPCA (Update W and sigma2)
def step_maximization_ppca(X, Z):
    pass

# PPCA training using EM
def train_ppca_em(X, latent_dim=2, n_steps=10, plot_intermediate=True):
    pass

# Generate data and run PPCA
X_ppca = generate_ppca_data()
plot_3d_data(X_ppca)  # Plot the original 3D data
train_ppca_em(X_ppca, latent_dim=2, n_steps=10)

# %% [markdown]
# ### Q2

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import StandardScaler

# Load MNIST dataset
mnist = fetch_openml('mnist_784')
data = mnist.data
labels = mnist.target.astype(int)

# Standardize the data
scaler = StandardScaler()
data = scaler.fit_transform(data)

# Function to initialize parameters for PPCA
def initialize_ppca(data, num_components):
    """ Initialize the PPCA parameters. """
    pass

# E-step of the PPCA
def e_step(data, mean, W, sigma2):
    """ E-step of the PPCA: Calculate the posterior distribution of the latent variables. """
    pass

# M-step of the PPCA
def m_step(data, Z, mean, W, sigma2):
    """ M-step of the PPCA: Update the parameters based on the current estimates. """
    pass

# PPCA using EM
def ppca_em(data, num_components, num_iterations):
    """ Train the PPCA model using the EM algorithm. """
    pass

# Run PPCA
num_components = 2  # Reduce to 2D
num_iterations = 100
mean, W, sigma2, Z = ppca_em(data, num_components, num_iterations)

# Plotting the results
def plot_latent_space(Z, labels):
    """ Plot the latent space with labels. """
    plt.figure(figsize=(10, 8))
    scatter = plt.scatter(Z[:, 0], Z[:, 1], c=labels, cmap='viridis', alpha=0.5, s=5)
    plt.colorbar(scatter, label='Digit Label')
    plt.title('Latent Space Representation of MNIST using PPCA')
    plt.xlabel('Latent Dimension 1')
    plt.ylabel('Latent Dimension 2')
    plt.grid()
    plt.show()

# Visualize the latent space
plot_latent_space(Z, labels)
