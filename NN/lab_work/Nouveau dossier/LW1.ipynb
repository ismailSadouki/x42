# %%
import numpy as np
import matplotlib.pyplot as plt

def mcculloch_pitts(inputs, weights, threshold):
    # 1. Calculate the weighted sum (dot product)
    summation = np.dot(inputs, weights)
    
    # 2. Apply the threshold logic
    if summation >= threshold:
        return 1
        
    else:
        return 0
j

V=np.array([[0,0], [0,1], [1,0], [1,1]])
weights= np.array ([1,1])
threshold=0.5

for i in range(4):
    inputs= V[i,]
    print( " OR gate, the output of ",V[i,] ,"is", mcculloch_pitts(inputs, weights, threshold))
threshold=1.5
for i in range(4):
    inputs= V[i,]
    print( " AND gate, the output of ",V[i,] ,"is",  mcculloch_pitts(inputs, weights, threshold))
# Out:
#  OR gate, the output of  [0 0] is 0
#  OR gate, the output of  [0 1] is 1
#  OR gate, the output of  [1 0] is 1
#  OR gate, the output of  [1 1] is 1
#  AND gate, the output of  [0 0] is 0
#  AND gate, the output of  [0 1] is 0
#  AND gate, the output of  [1 0] is 0
#  AND gate, the output of  [1 1] is 1

# %%
V1=np.array ([0,1])
V2=np.array ([1,0])
V3=np.array ([1,1])
V4=np.array ([0,0])
V=np.array([[0,0], [0,1], [1,0], [1,1]])
weights= np.array ([1,1])
threshold=0.5

for i in range(4):
    inputs= V[i,]
    print( " OR gate, the output of ",V[i,] ,"is",  mcculloch_pitts(inputs, weights, threshold))
threshold=1.5
for i in range(4):
    inputs= V[i,]
    print( " AND gate, the output of ",V[i,] ,"is",  mcculloch_pitts(inputs, weights, threshold))
# Out:
#  OR gate, the output of  [0 0] is 0
#  OR gate, the output of  [0 1] is 1
#  OR gate, the output of  [1 0] is 1
#  OR gate, the output of  [1 1] is 1
#  AND gate, the output of  [0 0] is 0
#  AND gate, the output of  [0 1] is 0
#  AND gate, the output of  [1 0] is 0
#  AND gate, the output of  [1 1] is 1

# %%
# 1. Data for the OR gate
X = np.array([[0,0], [0,1], [1,0], [1,1]])
y = np.array([0, 1, 1, 1])

# 2. YOUR PARAMETERS (Fill these in)
w1 = 1
w2 = 1
theta = 0.5  # We use 0.5 instead of 2 so the line passes BETWEEN the points (1.5 AND)

# 3. Plotting
plt.figure(figsize=(6,6))
for i in range(len(y)):
    plt.scatter(X[i,0], X[i,1], c=('red' if y[i]==0 else 'green'), s=100, edgecolors='k')

# 4. Drawing the separation line
x1_vals = np.linspace(-0.5, 1.5, 10)
x2_vals = (theta - w1 * x1_vals) / w2
plt.plot(x1_vals, x2_vals, '--b', label="Decision Boundary")

plt.xlim(-0.5, 1.5); plt.ylim(-0.5, 1.5)
plt.axhline(0, color='black', lw=1); plt.axvline(0, color='black', lw=1)
plt.legend(); plt.grid(True)
plt.title("M-P Neuron Decision Boundary (OR Gate)")
plt.show()

# %%
# Out:
# 4
